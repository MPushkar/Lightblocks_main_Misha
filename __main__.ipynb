# %% [markdown]
# This notebooK is used to perform the TEST of the "Lightblocks Full Raw Data" dataset to the "Lightblocks Full Processed Data" dataset.

# %%
print ('TEST1')
# Out:
# TEST1

# %%
from datetime import datetime

now = datetime.now()
print (now)
# Out:
# 2024-01-22 15:43:49.908058
